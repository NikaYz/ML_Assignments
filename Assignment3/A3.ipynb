# %% [markdown]
# ---
# K-MEANS CLUSTERING
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import random

headlines = pd.read_csv('headlines.csv')
tfidf_features = np.load('tfidf_features.npy')

# setting random to generate same result
np.random.seed(0)
random.seed(67)

# %%
print(headlines.shape)
print(tfidf_features.shape)
# Out:
# (19685, 2)
# (19685, 1000)

# %%
print(headlines.head(10))
# Out:
#    idx                                           headline
# 0    0  Country Living Appraises A 1950s Jiffy-Way Egg...
# 1    1  Kylie Jenner's Beauty Routine Is More Like You...
# 2    2  These Celebrity Vegetarians Will Pass On The T...
# 3    3                The Sharing Economy at a Crossroads
# 4    4                     What Happened To Scott Walker?
# 5    5  The 10 Most Influential People In Family Life ...
# 6    6  Do the Promenade at Three Peerless Florida Pie...
# 7    7  Writer Calls On Women Of Color 'To Divest From...
# 8    8  Single Mothers Aren't the Problem Today, Absen...
# 9    9  Fitness Chain Bans Cable News For Not Being Pa...

# %% [markdown]
# Divided the k clusters into different parts as while running it was not completing because of interent issues.

# %%
# using kmeans from 2 to 500 for k clusters
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

distortions = []
for k in range(2, 500):
    kmeans = KMeans(n_clusters=k, random_state=67,init = 'k-means++')
    print(k,end='')
    kmeans.fit(tfidf_features)
    distortions.append(kmeans.inertia_)

plt.plot(range(2, 500), distortions, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()
print(distortions)
# Out:
# ...
# ...

# %%
for i in range(distort):
    print(distortions[i])
# Out:
# 19377.880508443777
# 19264.949183633613
# 19219.98651368599
# 19152.365887633066
# 19101.189535305955
# 19100.41360220062
# 19031.466036368787
# 18979.525420893333
# 18834.985394332096
# 18791.092707718344
# 18750.07983171075
# 18685.179626123816
# 18545.583634483537
# 18487.923710345804
# 18453.514606946417
# 18412.30392858449
# 18363.311156958785
# 18318.186294882635
# 18246.370141418316
# 18194.30705063914
# 18130.41174453151
# 18089.58050524115
# 18056.540877171967
# 18025.141921290488
# 17980.0840449281
# 17943.0177378648
# 17905.578246765253
# 17893.03386589996
# 17875.91502665852
# 17852.41517119709
# 17808.70954623095
# 17754.282169551287
# 17693.005078909733
# 17640.182165149414
# 17587.907506078725
# 17556.800761032682
# 17517.64212424042
# 17455.217870848126
# 17400.3560880949
# 17373.313580813046
# 17361.768007724164
# 17332.67618765651
# 17305.133579770285
# 17283.942283556542
# 17262.265284727364
# 17237.64797992855
# 17206.125020444975
# 17185.290030726355
# ...

# %%
# kmeans for k = 500 to 650
m = []
for k in range( 500,650):
    kmeans = KMeans(n_clusters=k, random_state=67,init = 'k-means++')
    print(k,end='')
    kmeans.fit(tfidf_features)
    m.append(kmeans.inertia_)

plt.plot(range(500,650), m, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()
# Out:
# ...

# %%
# combining k clusters for 2 to 650
new = distortions + m
print(new)
plt.plot(range(2,650), new, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()
# Out:
# [19547.109752242486, 19377.880508443777, 19264.949183633613, 19219.98651368599, 19152.365887633066, 19101.189535305955, 19100.41360220062, 19031.466036368787, 18979.525420893333, 18834.985394332096, 18791.092707718344, 18750.07983171075, 18685.179626123816, 18545.583634483537, 18487.923710345804, 18453.514606946417, 18412.30392858449, 18363.311156958785, 18318.186294882635, 18246.370141418316, 18194.30705063914, 18130.41174453151, 18089.58050524115, 18056.540877171967, 18025.
def get_random_headlines_from_clusters(y_labels, headlines, num_headlines=3, num_clusters=3):
    cluster_headlines = {}
    for i, label in enumerate(y_labels):
        if label not in cluster_headlines:
            cluster_headlines[label] = []
        cluster_headlines[label].append(headlines[i])

    random_clusters = random.sample(list(cluster_headlines.keys()), min(num_clusters, len(cluster_headlines)))

    random_headlines = {}
    for cluster in random_clusters:
        cluster_headlines_list = cluster_headlines[cluster]
        random_headlines[cluster] = random.sample(cluster_headlines_list, min(num_headlines, len(cluster_headlines_list)))

    return random_headlines

random_headlines = get_random_headlines_from_clusters(y_labels, headlines, num_headlines=10, num_clusters=3)
# printing messages in the cluster
for cluster, headlines in random_headlines.items():
    print(f"Cluster {cluster}:")
    for headline in headlines:
        print(f"- {headline}")
    print()
# Out:
# Cluster 34:
# - 5 Racist Trump Moments From The First 2020 Presidential Debate
# - Cruz And Trump Make Final Appeals To Iowans
# - #Trump Or #Milosevic: Who's More Dangerous?
# - Trump Could Be Ordered To Testify In Lawsuit Alleging Violence By Security Guards
# - Trump: 'Very Important' For NFL Players To Stand For Anthem
# - Trump Mysteriously Scrambles His Ad Reservations In Crucial Swing States
# - Trump Wonders Why Japan, 'A Country Of Samurai Warriors,' Didn't Shoot Down Missiles
# - Clinton Leads Trump By 5 Points In Latest Poll
# - 3 Trump Speeches And The Death Of A Nation
# - Trump Orders Review Of U.S. Postal Service After Complaining That Amazon Was Taking Advantage
#
# Cluster 62:
# - Hillary Clinton Calls Out Debate Moderators For Ignoring Women's Health
# - Jimmy Fallon Calls Out Mystery Object Coming From Trump's Nose
# - Pope Francis Calls For Ban On Nuclear Weapons
# - Trump's Pick To Lead Health Agency Calls EpiPen Issue 'Disturbing'
# ...

# %% [markdown]
# ---
# HEIRARCHICAL CLUSTERING:
# ---

# %%
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
headlines = pd.read_csv('headlines.csv')
tfidf_features = np.load('tfidf_features.npy')

print(headlines.shape)
print(tfidf_features.shape)
# Out:
# (19685, 2)
# (19685, 1000)

# %%
np.random.seed(67)
random.seed(67)
subset_indices = np.random.choice(len(headlines), 1000, replace=False)
subset_tfidf = tfidf_features[subset_indices]
subset_headlines = headlines.iloc[subset_indices]

# %%
plt.figure(figsize=(100, 50))
dendrogram = sch.dendrogram(sch.linkage(subset_tfidf, method='ward'))
plt.title('Dendrogram')
plt.xlabel('Headlines')
plt.ylabel('Euclidean distances')
# used to observe which line is taken to consider for number of clusters
plt.axhline(y=1.63, color='r', linestyle='--')
plt.show()

# %% [markdown]
# Using what we got in kmeans clustering

# %%
# dividing tfidf into clusters
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=146, metric='euclidean', linkage='ward')
y_labels = cluster.fit_predict(subset_tfidf)

# %%
headlines = subset_headlines['headline'].tolist()
# getting random headlines for the generated clusters
def get_random_headlines_from_clusters(y_labels, headlines, num_headlines=3, num_clusters=3):

    cluster_headlines = {}
    for i, label in enumerate(y_labels):
        if label not in cluster_headlines:
            cluster_headlines[label] = []
        cluster_headlines[label].append(headlines[i])

    random_clusters = random.sample(list(cluster_headlines.keys()), min(num_clusters, len(cluster_headlines)))

    random_headlines = {}
    for cluster in random_clusters:
        cluster_headlines_list = cluster_headlines[cluster]
        random_headlines[cluster] = random.sample(cluster_headlines_list, min(num_headlines, len(cluster_headlines_list)))

    return random_headlines

random_headlines = get_random_headlines_from_clusters(y_labels, headlines, num_headlines=10, num_clusters=3)
# printing messages for the generated clusters
for cluster, headlines in random_headlines.items():
    print(f"Cluster {cluster}:")
    for headline in headlines:
        print(f"- {headline}")
    print()
# Out:
# Cluster 136:
# - WATCH: Livestreamed Canonizations of Popes John XXIII, JP2
# - John Kasich: Profiling Muslims Is A 'Knee-Jerk' Response To Terror
# - John Lennon's Killer Denied Parole For Eighth Time
# - Buckingham Palace Announces Prince Philip's Funeral Arrangements
# - John Travolta Is Very Thankful For 'Dick Poop'
# - John Oliver Proposes Some Of The Greatest Things That Don't Exist... Yet
# - Chief Justice John Roberts Uses Sign Language As Deaf Lawyers Sworn In
# - John Oliver Needles The 'Dangerously Unregulated' Rehab Industry
# - Red Sox Manager John Farrell Announces He Has Lymphoma
#
# Cluster 90:
# - ‘Bushy And The Donald Across America’ Is The Travel Show Of Your Nightmares
# - My Favorite 'Insider' Money Savers For Travel
# - Money Is Politics
# - Trump's Muslim Ban Faces Tough Questions From Appeals Court
# - Dirty Dozen Travel Myths
# - U.S. To Lift Travel Ban On 8 Southern African Countries
# ...

# %% [markdown]
# Difficult to observe the cluster in heirarchical clustering i.e 225

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=225, metric='euclidean', linkage='ward')
y_labels = cluster.fit_predict(subset_tfidf)

# %%
random.seed(67)
headlines = subset_headlines['headline'].tolist()
# to get random messsages form the generated cluster
def get_random_headlines_from_clusters(y_labels, headlines, num_headlines, num_clusters=3):
    cluster_headlines = {}
    for i, label in enumerate(y_labels):
        if label not in cluster_headlines:
            cluster_headlines[label] = []
        cluster_headlines[label].append(headlines[i])

    random_clusters = random.sample(list(cluster_headlines.keys()), min(num_clusters, len(cluster_headlines)))

    random_headlines = {}
    for cluster in random_clusters:
        cluster_headlines_list = cluster_headlines[cluster]
        random_headlines[cluster] = random.sample(cluster_headlines_list, min(num_headlines, len(cluster_headlines_list)))

    return random_headlines

random_headlines = get_random_headlines_from_clusters(y_labels, headlines, num_headlines=10, num_clusters=3)
# printing messages for the generated clusters
for cluster, headlines in random_headlines.items():
    print(f"Cluster {cluster}:")
    for headline in headlines:
        print(f"- {headline}")
    print()
# Out:
# Cluster 7:
# - John Kasich: Profiling Muslims Is A 'Knee-Jerk' Response To Terror
# - WATCH: Livestreamed Canonizations of Popes John XXIII, JP2
# - John Travolta Is Very Thankful For 'Dick Poop'
# - John Lennon's Killer Denied Parole For Eighth Time
# - Buckingham Palace Announces Prince Philip's Funeral Arrangements
# - Chief Justice John Roberts Uses Sign Language As Deaf Lawyers Sworn In
# - John Oliver Needles The 'Dangerously Unregulated' Rehab Industry
# - John Oliver Proposes Some Of The Greatest Things That Don't Exist... Yet
# - Red Sox Manager John Farrell Announces He Has Lymphoma
#
# Cluster 197:
# - Hundreds Of Scarves Hung In Veterans' Park To Bundle Those In Need
# - The 8 Photography Styles You Need To Know
# - Everything You Need To Know About Overdraft Fees [GRAPHIC]
# - Starbucks Will Donate Unsold Food To People In Need
#
# Cluster 198:
# - Philadelphia Church Shields Undocumented Father From Deportation
# ...
